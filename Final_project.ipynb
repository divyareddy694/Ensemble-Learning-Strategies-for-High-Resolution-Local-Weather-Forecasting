# %%
import pandas as pd

weather = pd.read_csv("weather.csv", index_col="DATE")

# %%
weather
# Out:
#                 STATION                                               NAME  \
# DATE
# 1980-01-01  USW00093814  CINCINNATI NORTHERN KENTUCKY INTERNATIONAL AIR...
# 1980-01-02  USW00093814  CINCINNATI NORTHERN KENTUCKY INTERNATIONAL AIR...
# 1980-01-03  USW00093814  CINCINNATI NORTHERN KENTUCKY INTERNATIONAL AIR...
# 1980-01-04  USW00093814  CINCINNATI NORTHERN KENTUCKY INTERNATIONAL AIR...
# 1980-01-05  USW00093814  CINCINNATI NORTHERN KENTUCKY INTERNATIONAL AIR...
# ...                 ...                                                ...
# 2024-02-01  USW00093814  CINCINNATI NORTHERN KENTUCKY INTERNATIONAL AIR...
# 2024-02-02  USW00093814  CINCINNATI NORTHERN KENTUCKY INTERNATIONAL AIR...
# 2024-02-03  USW00093814  CINCINNATI NORTHERN KENTUCKY INTERNATIONAL AIR...
# 2024-02-04  USW00093814  CINCINNATI NORTHERN KENTUCKY INTERNATIONAL AIR...
# 2024-02-05  USW00093814  CINCINNATI NORTHERN KENTUCKY INTERNATIONAL AIR...
#
# ...

# %%
null_pct = weather.apply(pd.isnull).sum()/weather.shape[0]
null_pct
# Out:
# STATION    0.000000
# NAME       0.000000
# ACMC       0.999876
# ACMH       0.642888
# ACSC       0.999876
# ACSH       0.642888
# AWND       0.090768
# FMTM       0.372509
# PGTM       0.332650
# PRCP       0.000000
# PSUN       0.984789
# SNOW       0.001552
# SNWD       0.001118
# TAVG       0.588626
# TMAX       0.000000
# TMIN       0.000000
# TSUN       0.696157
# WDF1       0.643137
# WDF2       0.357174
# WDF5       0.358354
# WDFG       0.644440
# WESD       0.626994
# WSF1       0.643137
# WSF2       0.357174
# WSF5       0.358354
# WSFG       0.644254
# WT01       0.485069
# WT02       0.950270
# WT03       0.886571
# WT04       0.988638
# WT05       0.975973
# WT06       0.985720
# WT07       0.989880
# WT08       0.759483
# WT09       0.992301
# WT10       0.999876
# WT11       0.997579
# WT13       0.798783
# WT14       0.944124
# WT15       0.995095
# WT16       0.681070
# WT17       0.994909
# WT18       0.908860
# WT19       0.998696
# WT21       0.991308
# ...

# %%
valid_columns = weather.columns[null_pct < .05]

# %%
valid_columns
# Out:
# Index(['STATION', 'NAME', 'PRCP', 'SNOW', 'SNWD', 'TMAX', 'TMIN'], dtype='object')

# %%
weather = weather[valid_columns].copy()

# %%
weather.columns = weather.columns.str.lower()

# %%
weather
# Out:
#                 station                                               name  \
# DATE
# 1980-01-01  USW00093814  CINCINNATI NORTHERN KENTUCKY INTERNATIONAL AIR...
# 1980-01-02  USW00093814  CINCINNATI NORTHERN KENTUCKY INTERNATIONAL AIR...
# 1980-01-03  USW00093814  CINCINNATI NORTHERN KENTUCKY INTERNATIONAL AIR...
# 1980-01-04  USW00093814  CINCINNATI NORTHERN KENTUCKY INTERNATIONAL AIR...
# 1980-01-05  USW00093814  CINCINNATI NORTHERN KENTUCKY INTERNATIONAL AIR...
# ...                 ...                                                ...
# 2024-02-01  USW00093814  CINCINNATI NORTHERN KENTUCKY INTERNATIONAL AIR...
# 2024-02-02  USW00093814  CINCINNATI NORTHERN KENTUCKY INTERNATIONAL AIR...
# 2024-02-03  USW00093814  CINCINNATI NORTHERN KENTUCKY INTERNATIONAL AIR...
# 2024-02-04  USW00093814  CINCINNATI NORTHERN KENTUCKY INTERNATIONAL AIR...
# 2024-02-05  USW00093814  CINCINNATI NORTHERN KENTUCKY INTERNATIONAL AIR...
#
#             prcp  snow  snwd  tmax  tmin
# DATE
# ...

# %%
weather = weather.ffill()

# %%
weather.apply(pd.isnull).sum()
# Out:
# station    0
# name       0
# prcp       0
# snow       0
# snwd       0
# tmax       0
# tmin       0
# dtype: int64

# %%
weather.apply(lambda x: (x == 9999).sum())
# Out:
# station    0
# name       0
# prcp       0
# snow       0
# snwd       0
# tmax       0
# tmin       0
# dtype: int64

# %%
weather.dtypes
# Out:
# station     object
# name        object
# prcp       float64
# snow       float64
# snwd       float64
# tmax         int64
# tmin         int64
# dtype: object

# %%
weather.index
# Out:
# Index(['1980-01-01', '1980-01-02', '1980-01-03', '1980-01-04', '1980-01-05',
#        '1980-01-06', '1980-01-07', '1980-01-08', '1980-01-09', '1980-01-10',
#        ...
#        '2024-01-27', '2024-01-28', '2024-01-29', '2024-01-30', '2024-01-31',
#        '2024-02-01', '2024-02-02', '2024-02-03', '2024-02-04', '2024-02-05'],
#       dtype='object', name='DATE', length=16107)

# %%
weather.index = pd.to_datetime(weather.index)

# %%
weather.index.year.value_counts().sort_index()
# Out:
# 1980    366
# 1981    365
# 1982    365
# 1983    365
# 1984    366
# 1985    365
# 1986    365
# 1987    365
# 1988    366
# 1989    365
# 1990    365
# 1991    365
# 1992    366
# 1993    365
# 1994    365
# 1995    365
# 1996    366
# 1997    365
# 1998    365
# 1999    365
# 2000    366
# 2001    365
# 2002    365
# 2003    365
# 2004    366
# 2005    365
# 2006    365
# 2007    365
# 2008    366
# 2009    365
# 2010    365
# 2011    365
# 2012    366
# 2013    365
# 2014    365
# 2015    365
# 2016    366
# 2017    365
# 2018    365
# 2019    365
# 2020    366
# 2021    365
# 2022    365
# 2023    365
# 2024     36
# Name: DATE, dtype: int64

# %%
weather["snwd"].plot()
# Out:
# <Axes: xlabel='DATE'>

# %%
weather["target"] = weather.shift(-1)["tmax"]

# %%
weather
# Out:
#                 station                                               name  \
# DATE
# 1980-01-01  USW00093814  CINCINNATI NORTHERN KENTUCKY INTERNATIONAL AIR...
# 1980-01-02  USW00093814  CINCINNATI NORTHERN KENTUCKY INTERNATIONAL AIR...
# 1980-01-03  USW00093814  CINCINNATI NORTHERN KENTUCKY INTERNATIONAL AIR...
# 1980-01-04  USW00093814  CINCINNATI NORTHERN KENTUCKY INTERNATIONAL AIR...
# 1980-01-05  USW00093814  CINCINNATI NORTHERN KENTUCKY INTERNATIONAL AIR...
# ...                 ...                                                ...
# 2024-02-01  USW00093814  CINCINNATI NORTHERN KENTUCKY INTERNATIONAL AIR...
# 2024-02-02  USW00093814  CINCINNATI NORTHERN KENTUCKY INTERNATIONAL AIR...
# 2024-02-03  USW00093814  CINCINNATI NORTHERN KENTUCKY INTERNATIONAL AIR...
# 2024-02-04  USW00093814  CINCINNATI NORTHERN KENTUCKY INTERNATIONAL AIR...
# 2024-02-05  USW00093814  CINCINNATI NORTHERN KENTUCKY INTERNATIONAL AIR...
#
#             prcp  snow  snwd  tmax  tmin  target
# DATE
# ...

# %%
weather = weather.ffill()

# %%
weather
# Out:
#                 station                                               name  \
# DATE
# 1980-01-01  USW00093814  CINCINNATI NORTHERN KENTUCKY INTERNATIONAL AIR...
# 1980-01-02  USW00093814  CINCINNATI NORTHERN KENTUCKY INTERNATIONAL AIR...
# 1980-01-03  USW00093814  CINCINNATI NORTHERN KENTUCKY INTERNATIONAL AIR...
# 1980-01-04  USW00093814  CINCINNATI NORTHERN KENTUCKY INTERNATIONAL AIR...
# 1980-01-05  USW00093814  CINCINNATI NORTHERN KENTUCKY INTERNATIONAL AIR...
# ...                 ...                                                ...
# 2024-02-01  USW00093814  CINCINNATI NORTHERN KENTUCKY INTERNATIONAL AIR...
# 2024-02-02  USW00093814  CINCINNATI NORTHERN KENTUCKY INTERNATIONAL AIR...
# 2024-02-03  USW00093814  CINCINNATI NORTHERN KENTUCKY INTERNATIONAL AIR...
# 2024-02-04  USW00093814  CINCINNATI NORTHERN KENTUCKY INTERNATIONAL AIR...
# 2024-02-05  USW00093814  CINCINNATI NORTHERN KENTUCKY INTERNATIONAL AIR...
#
#             prcp  snow  snwd  tmax  tmin  target
# DATE
# ...

# %%
from sklearn.linear_model import Ridge

rr = Ridge(alpha=.1)

# %%
predictors = weather.columns[~weather.columns.isin(["target", "name", "station"])]

# %%
def backtest(weather, model, predictors, start=3650, step=90):
    all_predictions = []
    
    for i in range(start, weather.shape[0], step):
        train = weather.iloc[:i,:]
        test = weather.iloc[i:(i+step),:]
        
        model.fit(train[predictors], train["target"])
        
        preds = model.predict(test[predictors])
        preds = pd.Series(preds, index=test.index)
        combined = pd.concat([test["target"], preds], axis=1)
        combined.columns = ["actual", "prediction"]
        combined["diff"] = (combined["prediction"] - combined["actual"]).abs()
        
        all_predictions.append(combined)
    return pd.concat(all_predictions)

# %%
predictions = backtest(weather, rr, predictors)

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error

mean_absolute_error(predictions["actual"], predictions["prediction"])
# Out:
# 5.787716001009033

# %%
predictions.sort_values("diff", ascending=False)
# Out:
#             actual  prediction       diff
# DATE
# 2015-01-04    23.0   56.805811  33.805811
# 1990-12-27    45.0   11.577961  33.422039
# 2022-03-29    80.0   47.110133  32.889867
# 1990-12-30    23.0   54.644206  31.644206
# 2014-01-27     9.0   40.556969  31.556969
# ...            ...         ...        ...
# 2006-06-26    82.0   82.005481   0.005481
# 1998-08-28    83.0   82.994840   0.005160
# 2016-12-09    30.0   30.004487   0.004487
# 2006-11-26    63.0   63.001585   0.001585
# 2003-01-04    37.0   37.000025   0.000025
#
# [12457 rows x 3 columns]

# %%
pd.Series(rr.coef_, index=predictors)
# Out:
# prcp   -4.785789
# snow   -1.909420
# snwd    0.296808
# tmax    0.732346
# tmin    0.211625
# dtype: float64

# %%
def pct_diff(old, new):
    return (new - old) / old

def compute_rolling(weather, horizon, col):
    label = f"rolling_{horizon}_{col}"
    weather[label] = weather[col].rolling(horizon).mean()
    weather[f"{label}_pct"] = pct_diff(weather[label], weather[col])
    return weather
    
rolling_horizons = [3, 14]
for horizon in rolling_horizons:
    for col in ["tmax", "tmin", "prcp"]:
        weather = compute_rolling(weather, horizon, col)

# %%
def expand_mean(df):
    return df.expanding(1).mean()

for col in ["tmax", "tmin", "prcp"]:
    weather[f"month_avg_{col}"] = weather[col].groupby(weather.index.month, group_keys=False).apply(expand_mean)
    weather[f"day_avg_{col}"] = weather[col].groupby(weather.index.day_of_year, group_keys=False).apply(expand_mean)

# %%
weather = weather.iloc[14:,:]
weather = weather.fillna(0)

# %%
predictors = weather.columns[~weather.columns.isin(["target", "name", "station"])]

# %%
mae = mean_absolute_error(predictions["actual"], predictions["prediction"])

print("Mean Absolute Error:", mae)
# Out:
# Mean Absolute Error: 5.787716001009033

# %%
mean_squared_error(predictions["actual"], predictions["prediction"])
# Out:
# 57.093991161712495

# %%
predictions.sort_values("diff", ascending=False)
# Out:
#             actual  prediction       diff
# DATE
# 2015-01-04    23.0   56.805811  33.805811
# 1990-12-27    45.0   11.577961  33.422039
# 2022-03-29    80.0   47.110133  32.889867
# 1990-12-30    23.0   54.644206  31.644206
# 2014-01-27     9.0   40.556969  31.556969
# ...            ...         ...        ...
# 2006-06-26    82.0   82.005481   0.005481
# 1998-08-28    83.0   82.994840   0.005160
# 2016-12-09    30.0   30.004487   0.004487
# 2006-11-26    63.0   63.001585   0.001585
# 2003-01-04    37.0   37.000025   0.000025
#
# [12457 rows x 3 columns]

# %%
weather.loc["1990-03-07": "1990-03-17"]
# Out:
#                 station                                               name  \
# DATE
# 1990-03-07  USW00093814  CINCINNATI NORTHERN KENTUCKY INTERNATIONAL AIR...
# 1990-03-08  USW00093814  CINCINNATI NORTHERN KENTUCKY INTERNATIONAL AIR...
# 1990-03-09  USW00093814  CINCINNATI NORTHERN KENTUCKY INTERNATIONAL AIR...
# 1990-03-10  USW00093814  CINCINNATI NORTHERN KENTUCKY INTERNATIONAL AIR...
# 1990-03-11  USW00093814  CINCINNATI NORTHERN KENTUCKY INTERNATIONAL AIR...
# 1990-03-12  USW00093814  CINCINNATI NORTHERN KENTUCKY INTERNATIONAL AIR...
# 1990-03-13  USW00093814  CINCINNATI NORTHERN KENTUCKY INTERNATIONAL AIR...
# 1990-03-14  USW00093814  CINCINNATI NORTHERN KENTUCKY INTERNATIONAL AIR...
# 1990-03-15  USW00093814  CINCINNATI NORTHERN KENTUCKY INTERNATIONAL AIR...
# 1990-03-16  USW00093814  CINCINNATI NORTHERN KENTUCKY INTERNATIONAL AIR...
# 1990-03-17  USW00093814  CINCINNATI NORTHERN KENTUCKY INTERNATIONAL AIR...
#
# ...

# %%
(predictions["diff"].round().value_counts().sort_index() / predictions.shape[0]).plot()
# Out:
# <Axes: >

# %%
predictions
# Out:
#             actual  prediction       diff
# DATE
# 1989-12-29    52.0   44.095259   7.904741
# 1989-12-30    53.0   54.145149   1.145149
# 1989-12-31    34.0   51.323662  17.323662
# 1990-01-01    43.0   37.387027   5.612973
# 1990-01-02    48.0   44.529418   3.470582
# ...            ...         ...        ...
# 2024-02-01    48.0   54.448465   6.448465
# 2024-02-02    49.0   50.266015   1.266015
# 2024-02-03    56.0   50.363487   5.636513
# 2024-02-04    54.0   55.913157   1.913157
# 2024-02-05    54.0   53.813591   0.186409
#
# [12457 rows x 3 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Create a heatmap of the rounded differences
plt.figure(figsize=(10, 6))
sns.heatmap(predictions["diff"].round().value_counts().sort_index().to_frame(), cmap="Blues", annot=True, fmt='d')
plt.title("Distribution of Rounded Differences between Actual and Predicted Values")
plt.xlabel("Rounded Difference")
plt.ylabel("Frequency")
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.histplot(predictions["diff"], bins=20, kde=True)
plt.title("Histogram of Residuals")
plt.xlabel("Residuals")
plt.ylabel("Frequency")
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.scatter(predictions["actual"], predictions["prediction"], alpha=0.5)
plt.title("Scatter Plot of Actual vs. Predicted Values")
plt.xlabel("Actual Values")
plt.ylabel("Predicted Values")
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.plot(predictions.index, predictions["actual"], label="Actual", linestyle="-", color="red")
plt.plot(predictions.index, predictions["prediction"], label="Predicted", linestyle="--", color="blue")
plt.title("Time Series Plot of Actual vs. Predicted Values")
plt.xlabel("Date")
plt.ylabel("Values")
plt.legend()
plt.show()

# %%
max_residual = predictions["diff"].max()

# %%
max_residual
# Out:
# 33.805811037041686
